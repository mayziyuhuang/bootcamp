# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
rc={'lines.linewidth': 2, 'axes.labelsize': 18, 'axes.titlesize': 18}
sns.set(rc=rc)
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import bokeh.io
import bokeh.mpl
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bb1a2e9b-ea74-493d-abd8-052f999356dc">Loading BokehJS ...</span>
#     </div>

# %%
print('Hello, world')
# Out:
# Hello, world

# %%
5 + 1
# Out:
# 6

# %% [markdown]
#  type esc + m
#  then you can type
#
#  > this is important
#
#  > use '>' you can shift the line
#
#  # header
#  * important
#
#  * you can make an item
#
#  to type function use latex format
#
#  $\frac{1}{2}$
#
#  $\left(\frac{1}{2}\right)$

# %%
# Load in DataFrame
df = pd.read_csv('data/grant_1987.csv', comment='#')

# Change labels
df.columns = ['band', 'species', 'beak_length', 'beak_depth']

# %%
df
# Out:
#       band   species  beak_length  beak_depth
# 0    14613    fortis         9.10        7.00
# 1    15487    fortis         9.14        7.12
# 2    15187    fortis         9.24        7.21
# 3    15284    fortis         9.20        7.30
# 4    14983    fortis         8.83        7.32
# 5    14913    fortis         9.14        7.41
# 6    15726    fortis         9.04        7.42
# 7    15821    fortis        10.56        7.43
# 8    15484    fortis         9.70        7.45
# 9     4968    fortis         9.25        7.50
# 10   15695    fortis         9.50        7.50
# 11   15272    fortis         9.34        7.51
# 12   15256    fortis         9.64        7.51
# 13   13907    fortis         9.04        7.64
# 14    5578    fortis         9.80        7.65
# 15   10376    fortis         9.28        7.68
# 16   13377    fortis         9.50        7.70
# 17   15225    fortis        10.80        7.80
# 18   15914    fortis         9.24        7.81
# 19   14760    fortis        10.24        7.81
# 20   15779    fortis         9.74        7.86
# 21   13901    fortis         9.20        7.90
# 22   15277    fortis         9.95        7.90
# 23   15285    fortis         9.34        7.92
# 24   13194    fortis         9.35        7.92
# 25   14967    fortis        10.10        7.92
# 26   14800    fortis         9.96        7.93
# 27   14612    fortis         9.27        7.95
# 28   15154    fortis         9.40        7.95
# 29   14123    fortis         9.68        7.96
# ..     ...       ...          ...         ...
# 913  15694  scandens        13.14        9.51
# 914  15421  scandens        14.44        9.51
# 915  14208  scandens        12.73        9.52
# 916   1396  scandens        15.04        9.54
# 917   1444  scandens        14.85        9.55
# 918   4051  scandens        14.20        9.60
# 919  10061  scandens        15.20        9.60
# 920   4701  scandens        16.00        9.60
# 921  13257  scandens        14.47        9.62
# 922   2949  scandens        14.54        9.64
# 923  14946  scandens        14.90        9.65
# 924   5656  scandens        14.90        9.70
# 925   5608  scandens        15.80        9.70
# 926  15352  scandens        13.46        9.73
# 927  15817  scandens        14.77        9.73
# 928   4119  scandens        14.44        9.74
# 929  10223  scandens        15.20        9.80
# 930   2969  scandens        16.00        9.80
# 931  14648  scandens        14.40        9.82
# 932  15658  scandens        14.45        9.85
# 933  13256  scandens        15.35        9.85
# 934   8425  scandens        14.20        9.90
# 935  14524  scandens        15.30        9.90
# 936  10075  scandens        14.27        9.94
# 937   4137  scandens        15.80       10.00
# 938  14847  scandens        15.30       10.10
# 939  15886  scandens        11.24       10.11
# 940  14877  scandens        15.20       10.27
# 941   8036  scandens        15.44       10.34
# 942  14579  scandens        14.96       11.33
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Beak length versus beak depth
#
# This is a plot of beak length versus beak depth.

# %%
# Slice data from DataFrame
fortis_depth = df[df['species']=='fortis']['beak_depth']
scandens_depth = df[df['species']=='scandens']['beak_depth']
fortis_length = df[df['species']=='fortis']['beak_length']
scandens_length = df[df['species']=='scandens']['beak_length']

# Make plot
plt.plot(fortis_length, fortis_depth, marker='o', markersize=6, linestyle='', 
         alpha=0.5)
plt.plot(scandens_length, scandens_depth, marker='o', linestyle='', markersize=6,
         alpha=0.5, color=sns.color_palette()[2])
plt.margins(0.02)
plt.xlabel('beak length (mm)')
plt.ylabel('beak depth (mm)')

# make it interactive
bokeh.plotting.show(bokeh.mpl.to_bokeh())
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="561fe0aa-d0d5-43ba-ab91-2f78be7db2cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#561fe0aa-d0d5-43ba-ab91-2f78be7db2cb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("561fe0aa-d0d5-43ba-ab91-2f78be7db2cb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '561fe0aa-d0d5-43ba-ab91-2f78be7db2cb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"765d1e30-0d15-4726-a118-45655e2540d0":{"roots":{"references":[{"attributes":{"axis_label":"beak depth (mm)","axis_label_text_font":"sans-serif","axis_label_text_font_size":{"value":"18.000000pt"},"axis_label_text_font_style":"normal","formatter":{"id":"13033b5a-9034-4352-946e-50757e738a7f","type":"BasicTickFormatter"},"major_label_text_font":"sans-serif","major_label_text_font_size":{"value":"10.000000pt"},"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"},"ticker":{"id":"b444b12d-2b50-4406-8922-ff48a8832b69","type":"BasicTicker"}},"id":"a666c018-a5b8-4561-b996-5994852eb732","type":"LinearAxis"},{"attributes":{},"id":"b444b12d-2b50-4406-8922-ff48a8832b69","type":"BasicTicker"},{"attributes":{},"id":"13033b5a-9034-4352-946e-50757e738a7f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"337e5a7f-9c42-4448-a12c-01ed004b3eef","type":"ColumnDataSource"},"glyph":{"id":"c86743f1-c3dd-457c-8059-f1076abe99a0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f5bd0943-9811-4158-8cbd-5fea281eaf85","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"}},"id":"6928e5e2-a1bb-4437-903a-aa4461c73011","type":"SaveTool"},{"attributes":{"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"}},"id":"4523d4a8-27b4-4020-bf95-d0d59790ccb5","type":"HelpTool"},{"attributes":{"callback":null},"id":"93cbb5d6-2246-4ac8-aea2-96a5e2e57aae","type":"DataRange1d"},{"attributes":{"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"}},"id":"0d08af7d-2a68-4fb4-bad4-62db0a282f9c","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"24a2f85e-886b-4e8c-8a44-47459ab94fea","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"24a2f85e-886b-4e8c-8a44-47459ab94fea","type":"BoxAnnotation"},"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"}},"id":"d850cd7d-1ae7-465e-86a9-9b55e42553cc","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"fa26b289-4b80-448e-bcd9-f01029c79571","type":"Title"},{"attributes":{"plot":{"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"}},"id":"0d02ef44-14d8-4fdd-9b0f-3eaaed87afbe","type":"WheelZoomTool"},{"attributes":{"background_fill_color":{"value":"#EAEAF2"},"below":[{"id":"a7ebb318-3eaf-4b83-93fd-a60f4caaefe2","type":"LinearAxis"}],"left":[{"id":"a666c018-a5b8-4561-b996-5994852eb732","type":"LinearAxis"}],"plot_height":288,"plot_width":432,"renderers":[{"id":"a7ebb318-3eaf-4b83-93fd-a60f4caaefe2","type":"LinearAxis"},{"id":"e3581b47-08ba-4cb2-8684-48741c89da95","type":"Grid"},{"id":"a666c018-a5b8-4561-b996-5994852eb732","type":"LinearAxis"},{"id":"f37d32e5-e778-40f5-9bb3-f8d703200ea5","type":"Grid"},{"id":"24a2f85e-886b-4e8c-8a44-47459ab94fea","type":"BoxAnnotation"},{"id":"f5bd0943-9811-4158-8cbd-5fea281eaf85","type":"GlyphRenderer"},{"id":"02acd0d7-06e2-4eec-971f-854d53bd06d1","type":"GlyphRenderer"}],"title":{"id":"fa26b289-4b80-448e-bcd9-f01029c79571","type":"Title"},"tool_events":{"id":"c48816eb-420c-4e15-a36d-bb54cf14447f","type":"ToolEvents"},"toolbar":{"id":"3eb00823-90a2-492a-9d59-0e93e40ae5ca","type":"Toolbar"},"x_range":{"id":"93cbb5d6-2246-4ac8-aea2-96a5e2e57aae","type":"DataRange1d"},"y_range":{"id":"11df7f3e-cf6b-42cc-b005-516b9e0eb793","type":"DataRange1d"}},"id":"d11d48b8-a93f-4437-bc13-596973a052e7","type":"Plot"},{"attributes":{},"id":"0d7d2135-01d7-42de-ac44-0140f6a6ce80","type":"BasicTickFormatter"},{"attributes":{},"id":"f7c647ef-1c00-49e0-95a2-ea7038f0a720","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#C44E52"},"line_alpha":{"value":0.5},"line_color":{"value":"#000000"},"line_wid ...

# %%
# Plot with Bokeh, first make figure
p = bokeh.plotting.figure(height=400, width=500, x_axis_label='beak length (mm)',
                          y_axis_label='beak depth (mm)')

# Put in glyphs
p.circle(fortis_length, fortis_depth, color='dodgerblue', alpha=0.5, legend='fortis')
p.circle(scandens_length, scandens_depth, color='tomato', alpha=0.5, legend='scandens')

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c97feb17-e551-46cd-aef6-163f73d47655"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c97feb17-e551-46cd-aef6-163f73d47655").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c97feb17-e551-46cd-aef6-163f73d47655");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c97feb17-e551-46cd-aef6-163f73d47655' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3464dfc7-9de6-4235-809d-0c203c315a34":{"roots":{"references":[{"attributes":{"axis_label":"beak length (mm)","formatter":{"id":"cea93f4b-9717-413e-83e7-369c6a1ffe0b","type":"BasicTickFormatter"},"plot":{"id":"1a300934-26d7-4dfc-80fe-c294d37d6016","subtype":"Figure","type":"Plot"},"ticker":{"id":"356b5f84-5bdc-4807-8ddb-297314eebb7b","type":"BasicTicker"}},"id":"d5a065e0-2836-4844-b270-4b3a1b26c00e","type":"LinearAxis"},{"attributes":{"legends":[["fortis",[{"id":"47872e87-4dec-44a0-829f-d81a727d4488","type":"GlyphRenderer"}]],["scandens",[{"id":"65acbd4f-38f5-444b-9d81-a6ea65521ecb","type":"GlyphRenderer"}]]],"plot":{"id":"1a300934-26d7-4dfc-80fe-c294d37d6016","subtype":"Figure","type":"Plot"}},"id":"8f1f2759-6de9-4252-8fc6-0e9ace3d0fa9","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa106b6e-7da5-4a72-8686-5d54aafa5227","type":"Circle"},{"attributes":{"plot":{"id":"1a300934-26d7-4dfc-80fe-c294d37d6016","subtype":"Figure","type":"Plot"}},"id":"9e6d4dd7-e54b-4d3a-8ea0-e31534a33631","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"22a885d2-4cee-4031-ba7b-0f3e9e98f078","type":"ColumnDataSource"},"glyph":{"id":"2a0fa3cc-6f6d-449d-b5c2-7865ea16e3b3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"aa106b6e-7da5-4a72-8686-5d54aafa5227","type":"Circle"},"selection_glyph":null},"id":"65acbd4f-38f5-444b-9d81-a6ea65521ecb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"1a300934-26d7-4dfc-80fe-c294d37d6016","subtype":"Figure","type":"Plot