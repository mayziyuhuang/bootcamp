# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
rc={'lines.linewidth': 2, 'axes.labelsize': 18, 'axes.titlesize': 18}
sns.set(rc=rc)
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import bokeh.io
import bokeh.mpl
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7a839575-9951-41c7-a255-2b27b6455217">Loading BokehJS ...</span>
#     </div>

# %%
print('Hello, world')
# Out:
# Hello, world

# %%
5 + 1
# Out:
# 6

# %% [markdown]
#  type esc + m
#  then you can type
#
#  > this is important
#
#  > use '>' you can shift the line
#
#  # header
#  * important
#
#  * you can make an item
#
#  to type function use latex format
#
#  $\frac{1}{2}$
#
#  $\left(\frac{1}{2}\right)$

# %%
# Load in DataFrame
df = pd.read_csv('data/grant_1987.csv', comment='#')

# Change labels
df.columns = ['band', 'species', 'beak_length', 'beak_depth']

# %%
df
# Out:
#       band   species  beak_length  beak_depth
# 0    14613    fortis         9.10        7.00
# 1    15487    fortis         9.14        7.12
# 2    15187    fortis         9.24        7.21
# 3    15284    fortis         9.20        7.30
# 4    14983    fortis         8.83        7.32
# 5    14913    fortis         9.14        7.41
# 6    15726    fortis         9.04        7.42
# 7    15821    fortis        10.56        7.43
# 8    15484    fortis         9.70        7.45
# 9     4968    fortis         9.25        7.50
# 10   15695    fortis         9.50        7.50
# 11   15272    fortis         9.34        7.51
# 12   15256    fortis         9.64        7.51
# 13   13907    fortis         9.04        7.64
# 14    5578    fortis         9.80        7.65
# 15   10376    fortis         9.28        7.68
# 16   13377    fortis         9.50        7.70
# 17   15225    fortis        10.80        7.80
# 18   15914    fortis         9.24        7.81
# 19   14760    fortis        10.24        7.81
# 20   15779    fortis         9.74        7.86
# 21   13901    fortis         9.20        7.90
# 22   15277    fortis         9.95        7.90
# 23   15285    fortis         9.34        7.92
# 24   13194    fortis         9.35        7.92
# 25   14967    fortis        10.10        7.92
# 26   14800    fortis         9.96        7.93
# 27   14612    fortis         9.27        7.95
# 28   15154    fortis         9.40        7.95
# 29   14123    fortis         9.68        7.96
# ..     ...       ...          ...         ...
# 913  15694  scandens        13.14        9.51
# 914  15421  scandens        14.44        9.51
# 915  14208  scandens        12.73        9.52
# 916   1396  scandens        15.04        9.54
# 917   1444  scandens        14.85        9.55
# 918   4051  scandens        14.20        9.60
# 919  10061  scandens        15.20        9.60
# 920   4701  scandens        16.00        9.60
# 921  13257  scandens        14.47        9.62
# 922   2949  scandens        14.54        9.64
# 923  14946  scandens        14.90        9.65
# 924   5656  scandens        14.90        9.70
# 925   5608  scandens        15.80        9.70
# 926  15352  scandens        13.46        9.73
# 927  15817  scandens        14.77        9.73
# 928   4119  scandens        14.44        9.74
# 929  10223  scandens        15.20        9.80
# 930   2969  scandens        16.00        9.80
# 931  14648  scandens        14.40        9.82
# 932  15658  scandens        14.45        9.85
# 933  13256  scandens        15.35        9.85
# 934   8425  scandens        14.20        9.90
# 935  14524  scandens        15.30        9.90
# 936  10075  scandens        14.27        9.94
# 937   4137  scandens        15.80       10.00
# 938  14847  scandens        15.30       10.10
# 939  15886  scandens        11.24       10.11
# 940  14877  scandens        15.20       10.27
# 941   8036  scandens        15.44       10.34
# 942  14579  scandens        14.96       11.33
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Beak length versus beak depth
#
# This is a plot of beak length versus beak depth.

# %%
# Slice data from DataFrame
fortis_depth = df[df['species']=='fortis']['beak_depth']
scandens_depth = df[df['species']=='scandens']['beak_depth']
fortis_length = df[df['species']=='fortis']['beak_length']
scandens_length = df[df['species']=='scandens']['beak_length']

# Make plot
plt.plot(fortis_length, fortis_depth, marker='o', markersize=6, linestyle='', 
         alpha=0.5)
plt.plot(scandens_length, scandens_depth, marker='o', linestyle='', markersize=6,
         alpha=0.5, color=sns.color_palette()[2])
plt.margins(0.02)
plt.xlabel('beak length (mm)')
plt.ylabel('beak depth (mm)')

# make it interactive
bokeh.plotting.show(bokeh.mpl.to_bokeh())
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="99d64a72-0c5d-4150-b231-d637b9af372f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#99d64a72-0c5d-4150-b231-d637b9af372f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("99d64a72-0c5d-4150-b231-d637b9af372f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '99d64a72-0c5d-4150-b231-d637b9af372f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"271f8c6c-10fd-4db8-8b0f-a1b3c9e544d5":{"roots":{"references":[{"attributes":{"grid_line_color":{"value":"white"},"plot":{"id":"890b3ff6-a086-432b-88d6-b7a253df60cf","type":"Plot"},"ticker":{"id":"671cc117-49a6-4ee3-901d-e9432522e0c2","type":"BasicTicker"}},"id":"d8174e93-a8e0-43a7-bd51-5111fefbee43","type":"Grid"},{"attributes":{"data_source":{"id":"124a1ee6-df02-46d4-8e21-e74b51c922b5","type":"ColumnDataSource"},"glyph":{"id":"41f8f66a-f2b0-4934-93b9-64e3766d84a3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44abd93c-f257-48b5-8dc4-85eca0994ec7","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"890b3ff6-a086-432b-88d6-b7a253df60cf","type":"Plot"}},"id":"661fd93e-be07-4a83-91b1-ef2ad4fb9034","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#C44E52"},"line_alpha":{"value":0.5},"line_color":{"value":"#000000"},"line_width":{"value":0.0},"size":{"units":"screen","value":6.0},"x":{"field":"Series 0"},"y":{"field":"Series 1"}},"id":"41f8f66a-f2b0-4934-93b9-64e3766d84a3","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1efc9ddc-6373-443e-9ba7-1f70a9d5b09b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"890b3ff6-a086-432b-88d6-b7a253df60cf","type":"Plot"}},"id":"a632adef-53f3-42cc-ad6e-f12fb8bc3f2b","type":"WheelZoomTool"},{"attributes":{},"id":"c94bee54-f03c-4fe1-b76c-0f5aed3b0fc5","type":"BasicTicker"},{"attributes":{"overlay":{"id":"1efc9ddc-6373-443e-9ba7-1f70a9d5b09b","type":"BoxAnnotation"},"plot":{"id":"890b3ff6-a086-432b-88d6-b7a253df60cf","type":"Plot"}},"id":"94dfcbce-83c9-49e2-a55f-ed1035c6a611","type":"BoxZoomTool"},{"attributes":{},"id":"daba46eb-ba80-46ad-a0d2-5f2e8d89afdc","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":